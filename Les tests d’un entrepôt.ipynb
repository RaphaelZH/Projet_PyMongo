# %% [markdown]
# # Préparation

# %% [markdown]
# ## Installation des packages

# %%
import pymongo
from pymongo import MongoClient
import random
import datetime
from time import process_time
from pandas.core.frame import DataFrame

# %% [markdown]
# ## Connexion à la base de données

# %%
client = MongoClient(host="localhost", port=27017)
db = client["1_Warehouse"]

# %% [markdown]
# ## Accès des collections

# %%
Customer_1 = db["Customer_1"]
Order_1 = db["Order_1"]
Order_Line_1 = db["Order_Line_1"]
Semi_1 = db["Semi_1"]
Denormal_1 = db["Denormal_1"]

# %% [markdown]
# ## Création des variables aléatoires

# %%
district = str(random.randint(1, 10))
warehouse = str(random.randint(1, 1))
customer = str(random.randint(1, 3000))
daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# %% [markdown]
# # La requête C,  créer dix articles à une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
C_1_normal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_1.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1"
    })

    Order_Line_1.insert_many([{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "2",
                                  "ol_i_id": "785",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "7",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "3",
                                  "ol_i_id": "712",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "4",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "4",
                                  "ol_i_id": "1257",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "8",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "5",
                                  "ol_i_id": "2568",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "2",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "6",
                                  "ol_i_id": "6287",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "9",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "7",
                                  "ol_i_id": "7788",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "3",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "8",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "9",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "10",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                              }])
    end = process_time()
    time = end - start
    C_1_normal.append(time)
    i += 1
    j += 1
print(C_1_normal)
# Out:
# [0.002742000000000022, 0.0013100000000001444, 0.0013659999999999783, 0.0016100000000003334, 0.0016899999999999693, 0.0016499999999997073, 0.0016620000000000523, 0.0017819999999999503, 0.0018000000000002458, 0.0016320000000002999, 0.0015939999999998733, 0.0015920000000000378, 0.0015299999999998093, 0.0015819999999999723, 0.0012419999999999654, 0.0010799999999999699, 0.0010639999999999539, 0.0010900000000000354, 0.0011540000000000994, 0.0011820000000000164]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
C_1_semi = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    order_lines = [{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "2",
                       "ol_i_id": "785",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "7",
                       "ol_amount": "28.45",
                       "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "3",
                       "ol_i_id": "712",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "4",
                       "ol_amount": "28.45",
                       "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "4",
                       "ol_i_id": "1257",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "8",
                       "ol_amount": "28.45",
                       "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "5",
                       "ol_i_id": "2568",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "2",
                       "ol_amount": "28.45",
                       "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "6",
                       "ol_i_id": "6287",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "9",
                       "ol_amount": "28.45",
                       "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "7",
                       "ol_i_id": "7788",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "3",
                       "ol_amount": "28.45",
                       "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "8",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "9",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "10",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                   }]

    Semi_1.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    })
    end = process_time()
    time = end - start
    C_1_semi.append(time)
    i += 1
    j += 1
print(C_1_semi)
# Out:
# [0.0010759999999998549, 0.0008119999999998129, 0.0008780000000001564, 0.0009380000000001054, 0.0008680000000000909, 0.0007719999999999949, 0.0008499999999997954, 0.0009559999999999569, 0.0007820000000000604, 0.000612000000000279, 0.00055200000000033, 0.0005660000000000664, 0.0006260000000000154, 0.0006260000000000154, 0.0006299999999996864, 0.0006319999999999659, 0.0006399999999997519, 0.000576000000000132, 0.0005479999999997709, 0.0009219999999996453]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
C_1_denormal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_Info = Denormal_1.find_one({
        "$and": [{
            "c_id": customer
        }, {
            "c_d_id": district
        }, {
            "c_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "c_first": 1,
        "c_middle": 1,
        "c_last": 1,
        "c_street_1": 1,
        "c_street_2": 1,
        "c_city": 1,
        "c_state": 1,
        "c_zip": 1,
        "c_phone": 1,
        "c_since": 1,
        "c_credit": 1,
        "c_credit_lim": 1,
        "c_discount": 1,
        "c_balance": 1,
        "c_ytd_payment": 1,
        "c_payment_cnt": 1,
        "c_delivery_cnt": 1,
        "c_data": 1
    })
    customer_order = [{
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    }]

    Denormal_1.update_one({
        "c_id": customer,
        "c_d_id": district,
        "c_w_id": warehouse
    }, {
        "$set": {
            "c_first": Customer_Info.get("c_first"),
            "c_middle": Customer_Info.get("c_middle"),
            "c_last": Customer_Info.get("c_last"),
            "c_street_1": Customer_Info.get("c_street_1"),
            "c_street_2": Customer_Info.get("c_street_2"),
            "c_city": Customer_Info.get("c_city"),
            "c_state": Customer_Info.get("c_state"),
            "c_zip": Customer_Info.get("c_zip"),
            "c_phone": Customer_Info.get("c_phone"),
            "c_since": Customer_Info.get("c_since"),
            "c_credit": Customer_Info.get("c_credit"),
            "c_credit_lim": Customer_Info.get("c_credit_lim"),
            "c_discount": Customer_Info.get("c_first"),
            "c_balance": Customer_Info.get("c_balance"),
            "c_ytd_payment": Customer_Info.get("c_ytd_payment"),
            "c_payment_cnt": Customer_Info.get("c_payment_cnt"),
            "c_delivery_cnt": Customer_Info.get("c_delivery_cnt"),
            "c_data": Customer_Info.get("c_data"),
            "customer_order": customer_order
        }
    },
                          upsert=True)
    end = process_time()
    time = end - start
    C_1_denormal.append(time)
    i += 1
    j += 1
print(C_1_denormal)
# Out:
# [0.0026559999999999917, 0.0018780000000000463, 0.0012900000000000134, 0.0012660000000002114, 0.0011959999999997528, 0.001124000000000347, 0.0015000000000000568, 0.0015079999999998428, 0.0011220000000000674, 0.0011099999999997223, 0.001184000000000296, 0.0011359999999998038, 0.0012579999999999814, 0.0014959999999999418, 0.001196000000000197, 0.0010799999999999699, 0.0011540000000000994, 0.0010879999999997558, 0.0010380000000003164, 0.0011660000000000004]

# %% [markdown]
# # La requête R, chercher aléatoirement l’information d’un client

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
R_1_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_1.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Order_1.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_1_normal.append(time)
    i += 1
print(R_1_normal)
# Out:
# [0.001964000000000077, 0.0012979999999997993, 0.0014660000000001894, 0.0014440000000002229, 0.0013679999999998138, 0.0012539999999998663, 0.001148000000000149, 0.0011319999999996888, 0.0013540000000000774, 0.0011239999999999029, 0.001136000000000248, 0.0011220000000000674, 0.0011220000000000674, 0.0014479999999998938, 0.0012199999999999989, 0.0012219999999998343, 0.001368000000000258, 0.0012900000000000134, 0.0013620000000003074, 0.0013640000000001429]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
R_1_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_1.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Semi_1.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_1_semi.append(time)
    i += 1
print(R_1_semi)
# Out:
# [0.0017460000000002474, 0.0012279999999997848, 0.0011780000000003454, 0.0011120000000000019, 0.0011959999999997528, 0.0015420000000001544, 0.0011479999999997048, 0.0011199999999997878, 0.001104000000000216, 0.0012719999999997178, 0.001200000000000312, 0.0011839999999998518, 0.001132000000000133, 0.001120000000000232, 0.0011899999999998023, 0.0013000000000000789, 0.0012020000000001474, 0.0012919999999998488, 0.0013299999999998313, 0.0011420000000001984]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
R_1_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_1.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })
    Denormal_1.aggregate([{
        "$match": {
            "$and": [{
                "c_id": Customer_id.get("c_id")
            }, {
                "c_d_id": Customer_id.get("c_d_id")
            }, {
                "c_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "customer_order.o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "customer_order.o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_1_denormal.append(time)
    i += 1
print(R_1_denormal)
# Out:
# [0.0024519999999998987, 0.0013459999999998473, 0.0016619999999996082, 0.0018219999999997682, 0.0017160000000000508, 0.0017019999999998703, 0.0015119999999999578, 0.0013160000000000949, 0.001116000000000117, 0.0011079999999998869, 0.0011140000000002814, 0.0011619999999998853, 0.0010940000000001504, 0.0011600000000000499, 0.0011199999999997878, 0.001104000000000216, 0.0012020000000001474, 0.0012140000000000484, 0.0012300000000000644, 0.0012959999999999638]

# %% [markdown]
# # La requête U, modifier le temps de livraison des dix articles

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
U_1_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Order_Line_1.find_one_and_update({
            "ol_delivery_d": None
        }, {"$set": {
            "ol_delivery_d": daytime
        }},
                                         sort=[("ol_id", pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_1_normal.append(time)
    i += 1
print(U_1_normal)
# Out:
# [0.011153999999999886, 0.0089699999999997, 0.009454000000000296, 0.00873400000000002, 0.009095999999999993, 0.008127999999999691, 0.009339999999999904, 0.008446000000000176, 0.009156000000000386, 0.008796000000000248, 0.008287999999999851, 0.009078000000000142, 0.009162000000000337, 0.008671999999999791, 0.008640000000000203, 0.008253999999999984, 0.009074000000000026, 0.008823999999999721, 0.009112000000000009, 0.00843600000000011]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
U_1_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Semi_1.find_one_and_update({
            "order_lines.ol_delivery_d": None
        }, {"$set": {
            "order_lines.$.ol_delivery_d": daytime
        }},
                                   sort=[("order_lines.ol_id",
                                          pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_1_semi.append(time)
    i += 1
print(U_1_semi)
# Out:
# [0.011228000000000016, 0.011433999999999944, 0.01068200000000008, 0.010165999999999897, 0.009726000000000123, 0.009263999999999939, 0.009147999999999712, 0.010188000000000308, 0.009100000000000108, 0.009338000000000068, 0.009463999999999917, 0.009315999999999658, 0.009981999999999935, 0.009017999999999748, 0.009173999999999793, 0.009469999999999867, 0.009500000000000064, 0.009367999999999821, 0.009769999999999612, 0.009757999999999711]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
U_1_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Denormal_1.find_one_and_update({
            "customer_order.order_lines.ol_delivery_d":
            None
        }, {"$set": {
            "customer_order.0.order_lines.1.ol_delivery_d": daytime
        }},
                                       sort=[
                                           ("customer_order.order_lines.ol_id",
                                            pymongo.ASCENDING)
                                       ])
        j += 1
    end = process_time()
    time = end - start
    U_1_denormal.append(time)
    i += 1
print(U_1_denormal)
# Out:
# [0.012680000000000025, 0.01076200000000016, 0.010958000000000023, 0.011252000000000262, 0.01128399999999985, 0.011531999999999876, 0.01092800000000027, 0.01105199999999984, 0.011254000000000097, 0.011394000000000126, 0.010324000000000222, 0.011179999999999968, 0.011059999999999626, 0.011022000000000087, 0.010463999999999807, 0.011296000000000195, 0.011006000000000071, 0.010666000000000064, 0.010434000000000054, 0.01115200000000005]

# %% [markdown]
# # La requête D, supprimer aléatoirement d’une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
D_1_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_1.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Order_1.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    Order_1.delete_many({
        "$and": [{
            "ol_id": Order_Line_Info.get("ol_id")
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_1_normal.append(time)
    i += 1
print(D_1_normal)
# Out:
# [0.00270999999999999, 0.0016300000000000203, 0.0016020000000001033, 0.0015960000000001529, 0.0015979999999999883, 0.0016460000000000363, 0.0018199999999999328, 0.0018319999999998338, 0.0015779999999998573, 0.0019740000000001423, 0.0020919999999997607, 0.0017840000000002298, 0.0018780000000000463, 0.0017740000000001643, 0.0019059999999999633, 0.0020839999999999748, 0.0018020000000000813, 0.0016419999999999213, 0.0017320000000000668, 0.0016599999999997728]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
D_1_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_1.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Semi_1.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_1_semi.append(time)
    i += 1
print(D_1_semi)
# Out:
# [0.004081999999999919, 0.0012799999999999478, 0.0012560000000001459, 0.0013600000000000279, 0.0012579999999999814, 0.0013600000000000279, 0.0012460000000000804, 0.0012579999999999814, 0.00140000000000029, 0.0012240000000001139, 0.0011660000000000004, 0.0012900000000000134, 0.0010940000000001504, 0.0022679999999999367, 0.0014159999999998618, 0.0016680000000000028, 0.0017199999999997218, 0.0019320000000000448, 0.0015760000000000218, 0.001104000000000216]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
D_1_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 1))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_1.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Denormal_1.update_one({
        "customer_order.o_id": Order_Line_Info.get("ol_id"),
        "customer_order.o_d_id": district,
        "customer_order.o_w_id": warehouse
    }, {
        "$unset": {
            "customer_order._id": "",
            "customer_order.o_id": "",
            "customer_order.o_d_id": "",
            "customer_order.o_w_id": "",
            "customer_order.o_c_id": "",
            "customer_order.o_entry_d": "",
            "customer_order.o_carrier_id": "",
            "customer_order.o_ol_cnt": "",
            "customer_order.o_all_local": "",
            "customer_order.order_lines": ""
        }
    },
                          upsert=True)
    end = process_time()
    time = end - start
    D_1_denormal.append(time)
    i += 1
print(D_1_denormal)
# Out:
# [0.0019499999999998963, 0.0013579999999997483, 0.0013000000000000789, 0.0014159999999998618, 0.0015979999999999883, 0.0013819999999999943, 0.0012659999999997673, 0.0013800000000001589, 0.0016419999999999213, 0.0015160000000000728, 0.0014140000000000263, 0.0013819999999999943, 0.0014380000000002724, 0.0015640000000001208, 0.0014940000000001064, 0.0016419999999999213, 0.0015519999999997758, 0.0014599999999997948, 0.0015620000000002854, 0.0023379999999999512]

# %%
dic = {
    "C_1_normal": C_1_normal,
    "C_1_semi": C_1_semi,
    "C_1_denormal": C_1_denormal,
    "R_1_normal": R_1_normal,
    "R_1_semi": R_1_semi,
    "R_1_denormal": R_1_denormal,
    "U_1_normal": U_1_normal,
    "U_1_semi": U_1_semi,
    "U_1_denormal": U_1_denormal,
    "D_1_normal": D_1_normal,
    "D_1_semi": D_1_semi,
    "D_1_denormal": D_1_denormal
}

# %%
df = DataFrame(dic)
print(df)
# Out:
#     C_1_normal  C_1_semi  C_1_denormal  R_1_normal  R_1_semi  R_1_denormal  \
# 0     0.002742  0.001076      0.002656    0.001964  0.001746      0.002452
# 1     0.001310  0.000812      0.001878    0.001298  0.001228      0.001346
# 2     0.001366  0.000878      0.001290    0.001466  0.001178      0.001662
# 3     0.001610  0.000938      0.001266    0.001444  0.001112      0.001822
# 4     0.001690  0.000868      0.001196    0.001368  0.001196      0.001716
# 5     0.001650  0.000772      0.001124    0.001254  0.001542      0.001702
# 6     0.001662  0.000850      0.001500    0.001148  0.001148      0.001512
# 7     0.001782  0.000956      0.001508    0.001132  0.001120      0.001316
# 8     0.001800  0.000782      0.001122    0.001354  0.001104      0.001116
# 9     0.001632  0.000612      0.001110    0.001124  0.001272      0.001108
# 10    0.001594  0.000552      0.001184    0.001136  0.001200      0.001114
# 11    0.001592  0.000566      0.001136    0.001122  0.001184      0.001162
# 12    0.001530  0.000626      0.001258    0.001122  0.001132      0.001094
# 13    0.001582  0.000626      0.001496    0.001448  0.001120      0.001160
# 14    0.001242  0.000630      0.001196    0.001220  0.001190      0.001120
# 15    0.001080  0.000632      0.001080    0.001222  0.001300      0.001104
# 16    0.001064  0.000640      0.001154    0.001368  0.001202      0.001202
# 17    0.001090  0.000576      0.001088    0.001290  0.001292      0.001214
# 18    0.001154  0.000548      0.001038    0.001362  0.001330      0.001230
# 19    0.001182  0.000922      0.001166    0.001364  0.001142      0.001296
#
#     U_1_normal  U_1_semi  U_1_denormal  D_1_normal  D_1_semi  D_1_denormal
# 0     0.011154  0.011228      0.012680    0.002710  0.004082      0.001950
# 1     0.008970  0.011434      0.010762    0.001630  0.001280      0.001358
# 2     0.009454  0.010682      0.010958    0.001602  0.001256      0.001300
# 3     0.008734  0.010166      0.011252    0.001596  0.001360      0.001416
# 4     0.009096  0.009726      0.011284    0.001598  0.001258      0.001598
# 5     0.008128  0.009264      0.011532    0.001646  0.001360      0.001382
# 6     0.009340  0.009148      0.010928    0.001820  0.001246      0.001266
# 7     0.008446  0.010188      0.011052    0.001832  0.001258      0.001380
# 8     0.009156  0.009100      0.011254    0.001578  0.001400      0.001642
# 9     0.008796  0.009338      0.011394    0.001974  0.001224      0.001516
# 10    0.008288  0.009464      0.010324    0.002092  0.001166      0.001414
# 11    0.009078  0.009316      0.011180    0.001784  0.001290      0.001382
# 12    0.009162  0.009982      0.011060    0.001878  0.001094      0.001438
# 13    0.008672  0.009018      0.011022    0.001774  0.002268      0.001564
# 14    0.008640  0.009174      0.010464    0.001906  0.001416      0.001494
# 15    0.008254  0.009470      0.011296    0.002084  0.001668      0.001642
# 16    0.009074  0.009500      0.011006    0.001802  0.001720      0.001552
# 17    0.008824  0.009368      0.010666    0.001642  0.001932      0.001460
# 18    0.009112  0.009770      0.010434    0.001732  0.001576      0.001562
# 19    0.008436  0.009758      0.011152    0.001660  0.001104      0.002338

# %%
df.to_csv("tests_1.csv", index=False, sep=',')

# %%
df.describe()
# Out:
#        C_1_normal   C_1_semi  C_1_denormal  R_1_normal   R_1_semi  \
# count   20.000000  20.000000     20.000000   20.000000  20.000000
# mean     0.001518   0.000743      0.001322    0.001310   0.001237
# std      0.000378   0.000161      0.000373    0.000194   0.000157
# min      0.001064   0.000548      0.001038    0.001122   0.001104
# 25%      0.001227   0.000623      0.001124    0.001145   0.001140
# 50%      0.001587   0.000706      0.001190    0.001294   0.001193
# 75%      0.001653   0.000871      0.001341    0.001368   0.001277
# max      0.002742   0.001076      0.002656    0.001964   0.001746
#
#        R_1_denormal  U_1_normal   U_1_semi  U_1_denormal  D_1_normal  \
# count     20.000000   20.000000  20.000000     20.000000   20.000000
# mean       0.001372    0.008941   0.009755      0.011085    0.001817
# std        0.000347    0.000641   0.000685      0.000498    0.000263
# min        0.001094    0.008128   0.009018      0.010324    0.001578
# 25%        0.001119    0.008592   0.009303      0.010887    0.001639
# 50%        0.001222    0.008897   0.009485      0.011056    0.001779
# 75%        0.001549    0.009123   0.010028      0.011262    0.001885
# max        0.002452    0.011154   0.011434      0.012680    0.002710
#
#         D_1_semi  D_1_denormal
# count  20.000000     20.000000
# mean    0.001548      0.001533
# std     0.000664      0.000243
# min     0.001094      0.001266
# 25%     0.001254      0.001382
# 50%     0.001325      0.001477
# 75%     0.001599      0.001573
# max     0.004082      0.002338
