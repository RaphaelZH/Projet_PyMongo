# %% [markdown]
# # Préparation

# %% [markdown]
# ## Installation des packages

# %%
import pymongo
from pymongo import MongoClient
import random
import datetime
from time import process_time
from pandas.core.frame import DataFrame

# %% [markdown]
# ## Connexion à la base de données

# %%
client = MongoClient(host="localhost", port=27017)
db = client["10_Warehouses"]

# %% [markdown]
# ## Accès des collections

# %%
Customer_10 = db["Customer_10"]
Order_10 = db["Order_10"]
Order_Line_10 = db["Order_Line_10"]
Semi_10 = db["Semi_10"]
Denormal_10 = db["Denormal_10"]

# %% [markdown]
# ## Création des variables aléatoires

# %%
district = str(random.randint(1, 10))
warehouse = str(random.randint(1, 10))
customer = str(random.randint(1, 3000))
daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# %% [markdown]
# # La requête C,  créer dix articles à une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
C_10_normal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_10.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1"
    })

    Order_Line_10.insert_many([{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "2",
                                  "ol_i_id": "785",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "7",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "3",
                                  "ol_i_id": "712",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "4",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "4",
                                  "ol_i_id": "1257",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "8",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "5",
                                  "ol_i_id": "2568",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "2",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "6",
                                  "ol_i_id": "6287",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "9",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "7",
                                  "ol_i_id": "7788",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "3",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "8",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "9",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "10",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                              }])
    end = process_time()
    time = end - start
    C_10_normal.append(time)
    i += 1
    j += 1
print(C_10_normal)
# Out:
# [0.0028440000000000687, 0.0013819999999999943, 0.001416000000000306, 0.0014119999999997468, 0.0012639999999999318, 0.0013499999999999623, 0.0013159999999996508, 0.0012979999999997993, 0.0012859999999998983, 0.0013480000000001269, 0.0016680000000000028, 0.0012620000000000964, 0.0016460000000000363, 0.0019559999999998468, 0.0015399999999998748, 0.0014400000000001079, 0.0016859999999998543, 0.0019580000000001263, 0.0016620000000000523, 0.0014919999999998268]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
C_10_semi = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    order_lines = [{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "2",
                       "ol_i_id": "785",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "7",
                       "ol_amount": "28.45",
                       "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "3",
                       "ol_i_id": "712",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "4",
                       "ol_amount": "28.45",
                       "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "4",
                       "ol_i_id": "1257",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "8",
                       "ol_amount": "28.45",
                       "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "5",
                       "ol_i_id": "2568",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "2",
                       "ol_amount": "28.45",
                       "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "6",
                       "ol_i_id": "6287",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "9",
                       "ol_amount": "28.45",
                       "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "7",
                       "ol_i_id": "7788",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "3",
                       "ol_amount": "28.45",
                       "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "8",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "9",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "10",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                   }]

    Semi_10.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    })
    end = process_time()
    time = end - start
    C_10_semi.append(time)
    i += 1
    j += 1
print(C_10_semi)
# Out:
# [0.0015099999999996783, 0.001304000000000194, 0.0010500000000002174, 0.0010180000000001854, 0.0010439999999998228, 0.0009879999999999889, 0.0007679999999998799, 0.0009959999999997748, 0.0009459999999998914, 0.0009000000000001229, 0.0010419999999999874, 0.0010319999999999219, 0.0011639999999997208, 0.0009699999999996933, 0.0007999999999999119, 0.0008200000000000429, 0.000920000000000254, 0.0009999999999998899, 0.0007259999999997824, 0.0009659999999995783]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
C_10_denormal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_Info = Denormal_10.find_one({
        "$and": [{
            "c_id": customer
        }, {
            "c_d_id": district
        }, {
            "c_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "c_first": 1,
        "c_middle": 1,
        "c_last": 1,
        "c_street_1": 1,
        "c_street_2": 1,
        "c_city": 1,
        "c_state": 1,
        "c_zip": 1,
        "c_phone": 1,
        "c_since": 1,
        "c_credit": 1,
        "c_credit_lim": 1,
        "c_discount": 1,
        "c_balance": 1,
        "c_ytd_payment": 1,
        "c_payment_cnt": 1,
        "c_delivery_cnt": 1,
        "c_data": 1
    })
    customer_order = [{
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    }]

    Denormal_10.update_one({
        "c_id": customer,
        "c_d_id": district,
        "c_w_id": warehouse
    }, {
        "$set": {
            "c_first": Customer_Info.get("c_first"),
            "c_middle": Customer_Info.get("c_middle"),
            "c_last": Customer_Info.get("c_last"),
            "c_street_1": Customer_Info.get("c_street_1"),
            "c_street_2": Customer_Info.get("c_street_2"),
            "c_city": Customer_Info.get("c_city"),
            "c_state": Customer_Info.get("c_state"),
            "c_zip": Customer_Info.get("c_zip"),
            "c_phone": Customer_Info.get("c_phone"),
            "c_since": Customer_Info.get("c_since"),
            "c_credit": Customer_Info.get("c_credit"),
            "c_credit_lim": Customer_Info.get("c_credit_lim"),
            "c_discount": Customer_Info.get("c_first"),
            "c_balance": Customer_Info.get("c_balance"),
            "c_ytd_payment": Customer_Info.get("c_ytd_payment"),
            "c_payment_cnt": Customer_Info.get("c_payment_cnt"),
            "c_delivery_cnt": Customer_Info.get("c_delivery_cnt"),
            "c_data": Customer_Info.get("c_data"),
            "customer_order": customer_order
        }
    },
                          upsert=True)
    end = process_time()
    time = end - start
    C_10_denormal.append(time)
    i += 1
    j += 1
print(C_10_denormal)
# Out:
# [0.001988000000000323, 0.0018399999999996197, 0.0018959999999998978, 0.0018600000000001948, 0.0018600000000001948, 0.0018280000000001628, 0.0018380000000002283, 0.0019219999999999793, 0.0017860000000000653, 0.0017119999999999358, 0.0018739999999999313, 0.0012840000000000629, 0.0016539999999998223, 0.0017999999999998018, 0.0018839999999999968, 0.0018359999999999488, 0.0015000000000000568, 0.0015680000000002359, 0.0017080000000002649, 0.0015700000000000713]

# %% [markdown]
# # La requête R, chercher aléatoirement l’information d’un client

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
R_10_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_10.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Order_10.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_10_normal.append(time)
    i += 1
print(R_10_normal)
# Out:
# [0.0035719999999996865, 0.0017879999999999008, 0.0017000000000000348, 0.0018139999999999823, 0.0013940000000003394, 0.0014620000000000744, 0.0014600000000002389, 0.0016519999999999868, 0.0014199999999999768, 0.0015060000000000073, 0.0015220000000000233, 0.0014799999999999258, 0.0014119999999997468, 0.001244000000000245, 0.0012460000000000804, 0.0013920000000000599, 0.0014660000000001894, 0.0013659999999999783, 0.0013179999999999303, 0.0015480000000001048]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
R_10_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_10.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Semi_10.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_10_semi.append(time)
    i += 1
print(R_10_semi)
# Out:
# [0.0025200000000000777, 0.0018039999999999168, 0.0015479999999996608, 0.0014579999999999593, 0.0013580000000001924, 0.0013719999999999288, 0.0014980000000002214, 0.0012680000000000469, 0.0014080000000000759, 0.0013959999999997308, 0.0014219999999998123, 0.0013320000000001109, 0.0015520000000002199, 0.002129999999999743, 0.002817999999999987, 0.0015580000000001704, 0.0017740000000001643, 0.0016180000000001193, 0.0017000000000000348, 0.0018299999999999983]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
R_10_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_10.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })
    Denormal_10.aggregate([{
        "$match": {
            "$and": [{
                "c_id": Customer_id.get("c_id")
            }, {
                "c_d_id": Customer_id.get("c_d_id")
            }, {
                "c_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "customer_order.o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "customer_order.o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_10_denormal.append(time)
    i += 1
print(R_10_denormal)
# Out:
# [0.0032200000000002227, 0.0017160000000000508, 0.0016160000000002839, 0.0017640000000000988, 0.0014340000000001574, 0.0016820000000001833, 0.001572000000000351, 0.0013760000000000439, 0.0016379999999998063, 0.0016219999999997903, 0.0017759999999999998, 0.0018379999999997843, 0.0018780000000000463, 0.0025119999999998477, 0.004887999999999781, 0.0021340000000003023, 0.0017599999999999838, 0.0019659999999999123, 0.0024540000000001783, 0.0016240000000000698]

# %% [markdown]
# # La requête U, modifier le temps de livraison des dix articles

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
U_10_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Order_Line_10.find_one_and_update({
            "ol_delivery_d": None
        }, {"$set": {
            "ol_delivery_d": daytime
        }},
                                         sort=[("ol_id", pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_10_normal.append(time)
    i += 1
print(U_10_normal)
# Out:
# [0.01423400000000008, 0.013335999999999792, 0.012823999999999725, 0.013316000000000106, 0.012265999999999888, 0.013009999999999966, 0.011966000000000143, 0.012572000000000028, 0.012506000000000128, 0.012901999999999969, 0.014000000000000234, 0.011906000000000194, 0.013749999999999929, 0.012284000000000184, 0.012287999999999855, 0.013221999999999845, 0.01206800000000019, 0.012174000000000351, 0.012311999999999657, 0.013323999999999891]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
U_10_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Semi_10.find_one_and_update({
            "order_lines.ol_delivery_d": None
        }, {"$set": {
            "order_lines.$.ol_delivery_d": daytime
        }},
                                   sort=[("order_lines.ol_id",
                                          pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_10_semi.append(time)
    i += 1
print(U_10_semi)
# Out:
# [0.01807800000000004, 0.015172000000000185, 0.013446000000000069, 0.015665999999999958, 0.014498000000000122, 0.014708000000000165, 0.015991999999999784, 0.01515199999999961, 0.013415999999999872, 0.014035999999999937, 0.015283999999999853, 0.016573999999999867, 0.01972399999999963, 0.019867999999999775, 0.014164000000000065, 0.015118000000000187, 0.01329199999999986, 0.01446399999999981, 0.013758000000000159, 0.01398599999999961]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
U_10_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Denormal_10.find_one_and_update({
            "customer_order.order_lines.ol_delivery_d":
            None
        }, {"$set": {
            "customer_order.0.order_lines.1.ol_delivery_d": daytime
        }},
                                       sort=[
                                           ("customer_order.order_lines.ol_id",
                                            pymongo.ASCENDING)
                                       ])
        j += 1
    end = process_time()
    time = end - start
    U_10_denormal.append(time)
    i += 1
print(U_10_denormal)
# Out:
# [0.021995999999999682, 0.017412000000000205, 0.021388000000000407, 0.021560000000000024, 0.01865199999999989, 0.022235999999999922, 0.016647999999999996, 0.017870000000000275, 0.019981999999999722, 0.018031999999999826, 0.0205700000000002, 0.02300000000000013, 0.019053999999999682, 0.02660000000000018, 0.021868, 0.03195799999999993, 0.03024799999999983, 0.02466999999999997, 0.018677999999999972, 0.0165519999999999]

# %% [markdown]
# # La requête D, supprimer aléatoirement d’une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
D_10_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_10.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Order_10.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    Order_10.delete_many({
        "$and": [{
            "ol_id": Order_Line_Info.get("ol_id")
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_10_normal.append(time)
    i += 1
print(D_10_normal)
# Out:
# [0.005735999999999741, 0.0024439999999996687, 0.002424000000000426, 0.002080000000000304, 0.00214999999999943, 0.002508000000000621, 0.002585999999999977, 0.0023840000000001638, 0.0034520000000002327, 0.0024119999999996367, 0.002297999999999689, 0.002393999999999785, 0.002845999999999904, 0.003153999999999435, 0.002177999999999791, 0.0022359999999999047, 0.0026900000000003033, 0.0021160000000000068, 0.0026140000000003383, 0.0024620000000004083]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
D_10_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_10.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Semi_10.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_10_semi.append(time)
    i += 1
print(D_10_semi)
# Out:
# [0.0028120000000004808, 0.0018519999999995207, 0.0018639999999994217, 0.0021839999999997417, 0.0017439999999995237, 0.0024920000000001608, 0.0016820000000006274, 0.0023679999999997037, 0.0015359999999997598, 0.0018760000000002108, 0.0014779999999996463, 0.0014180000000001414, 0.0015859999999996433, 0.0015979999999995442, 0.0017599999999999838, 0.0015000000000000568, 0.0022919999999997387, 0.0012900000000000134, 0.0013239999999994367, 0.0028560000000004138]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
D_10_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 10))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_10.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Denormal_10.update_one({
        "customer_order.o_id": Order_Line_Info.get("ol_id"),
        "customer_order.o_d_id": district,
        "customer_order.o_w_id": warehouse
    }, {
        "$unset": {
            "customer_order._id": "",
            "customer_order.o_id": "",
            "customer_order.o_d_id": "",
            "customer_order.o_w_id": "",
            "customer_order.o_c_id": "",
            "customer_order.o_entry_d": "",
            "customer_order.o_carrier_id": "",
            "customer_order.o_ol_cnt": "",
            "customer_order.o_all_local": "",
            "customer_order.order_lines": ""
        }
    },
                          upsert=True)
    end = process_time()
    time = end - start
    D_10_denormal.append(time)
    i += 1
print(D_10_denormal)
# Out:
# [0.002508000000000621, 0.0022180000000000533, 0.0026159999999997297, 0.0021659999999998902, 0.0021799999999991826, 0.0018299999999999983, 0.001985999999999599, 0.0017839999999997858, 0.0016720000000001178, 0.0019179999999998643, 0.0023020000000002483, 0.001964000000000077, 0.0024079999999999657, 0.0017599999999999838, 0.0017700000000004934, 0.0018679999999999808, 0.0025040000000000617, 0.004061999999999344, 0.0019439999999999458, 0.0018900000000003914]

# %%
dic = {
    "C_10_normal": C_10_normal,
    "C_10_semi": C_10_semi,
    "C_10_denormal": C_10_denormal,
    "R_10_normal": R_10_normal,
    "R_10_semi": R_10_semi,
    "R_10_denormal": R_10_denormal,
    "U_10_normal": U_10_normal,
    "U_10_semi": U_10_semi,
    "U_10_denormal": U_10_denormal,
    "D_10_normal": D_10_normal,
    "D_10_semi": D_10_semi,
    "D_10_denormal": D_10_denormal
}

# %%
df = DataFrame(dic)
print(df)
# Out:
#     C_10_normal  C_10_semi  C_10_denormal  R_10_normal  R_10_semi  \
# 0      0.002844   0.001510       0.001988     0.003572   0.002520
# 1      0.001382   0.001304       0.001840     0.001788   0.001804
# 2      0.001416   0.001050       0.001896     0.001700   0.001548
# 3      0.001412   0.001018       0.001860     0.001814   0.001458
# 4      0.001264   0.001044       0.001860     0.001394   0.001358
# 5      0.001350   0.000988       0.001828     0.001462   0.001372
# 6      0.001316   0.000768       0.001838     0.001460   0.001498
# 7      0.001298   0.000996       0.001922     0.001652   0.001268
# 8      0.001286   0.000946       0.001786     0.001420   0.001408
# 9      0.001348   0.000900       0.001712     0.001506   0.001396
# 10     0.001668   0.001042       0.001874     0.001522   0.001422
# 11     0.001262   0.001032       0.001284     0.001480   0.001332
# 12     0.001646   0.001164       0.001654     0.001412   0.001552
# 13     0.001956   0.000970       0.001800     0.001244   0.002130
# 14     0.001540   0.000800       0.001884     0.001246   0.002818
# 15     0.001440   0.000820       0.001836     0.001392   0.001558
# 16     0.001686   0.000920       0.001500     0.001466   0.001774
# 17     0.001958   0.001000       0.001568     0.001366   0.001618
# 18     0.001662   0.000726       0.001708     0.001318   0.001700
# 19     0.001492   0.000966       0.001570     0.001548   0.001830
#
#     R_10_denormal  U_10_normal  U_10_semi  U_10_denormal  D_10_normal  \
# 0        0.003220     0.014234   0.018078       0.021996     0.005736
# 1        0.001716     0.013336   0.015172       0.017412     0.002444
# 2        0.001616     0.012824   0.013446       0.021388     0.002424
# 3        0.001764     0.013316   0.015666       0.021560     0.002080
# 4        0.001434     0.012266   0.014498       0.018652     0.002150
# 5        0.001682     0.013010   0.014708       0.022236     0.002508
# 6        0.001572     0.011966   0.015992       0.016648     0.002586
# 7        0.001376     0.012572   0.015152       0.017870     0.002384
# 8        0.001638     0.012506   0.013416       0.019982     0.003452
# 9        0.001622     0.012902   0.014036       0.018032     0.002412
# 10       0.001776     0.014000   0.015284       0.020570     0.002298
# 11       0.001838     0.011906   0.016574       0.023000     0.002394
# 12       0.001878     0.013750   0.019724       0.019054     0.002846
# 13       0.002512     0.012284   0.019868       0.026600     0.003154
# 14       0.004888     0.012288   0.014164       0.021868     0.002178
# 15       0.002134     0.013222   0.015118       0.031958     0.002236
# 16       0.001760     0.012068   0.013292       0.030248     0.002690
# 17       0.001966     0.012174   0.014464       0.024670     0.002116
# 18       0.002454     0.012312   0.013758       0.018678     0.002614
# 19       0.001624     0.013324   0.013986       0.016552     0.002462
#
#     D_10_semi  D_10_denormal
# 0    0.002812       0.002508
# 1    0.001852       0.002218
# 2    0.001864       0.002616
# 3    0.002184       0.002166
# 4    0.001744       0.002180
# 5    0.002492       0.001830
# 6    0.001682       0.001986
# 7    0.002368       0.001784
# 8    0.001536       0.001672
# 9    0.001876       0.001918
# 10   0.001478       0.002302
# 11   0.001418       0.001964
# 12   0.001586       0.002408
# 13   0.001598       0.001760
# 14   0.001760       0.001770
# 15   0.001500       0.001868
# 16   0.002292       0.002504
# 17   0.001290       0.004062
# 18   0.001324       0.001944
# 19   0.002856       0.001890

# %%
df.to_csv("tests_10.csv", index=False, sep=',')

# %%
df.describe()
# Out:
#        C_10_normal  C_10_semi  C_10_denormal  R_10_normal  R_10_semi  \
# count    20.000000  20.000000      20.000000    20.000000  20.000000
# mean      0.001561   0.000998       0.001760     0.001588   0.001668
# std       0.000368   0.000179       0.000171     0.000492   0.000403
# min       0.001262   0.000726       0.001284     0.001244   0.001268
# 25%       0.001340   0.000915       0.001695     0.001394   0.001405
# 50%       0.001428   0.000992       0.001832     0.001464   0.001550
# 75%       0.001664   0.001042       0.001864     0.001574   0.001782
# max       0.002844   0.001510       0.001988     0.003572   0.002818
#
#        R_10_denormal  U_10_normal  U_10_semi  U_10_denormal  D_10_normal  \
# count      20.000000    20.000000  20.000000      20.000000    20.000000
# mean        0.002024     0.012813   0.015320       0.021449     0.002658
# std         0.000800     0.000691   0.001922       0.004232     0.000801
# min         0.001376     0.011906   0.013292       0.016552     0.002080
# 25%         0.001623     0.012280   0.014023       0.018497     0.002282
# 50%         0.001762     0.012698   0.014913       0.020979     0.002434
# 75%         0.002008     0.013318   0.015747       0.022427     0.002633
# max         0.004888     0.014234   0.019868       0.031958     0.005736
#
#        D_10_semi  D_10_denormal
# count  20.000000      20.000000
# mean    0.001876       0.002167
# std     0.000472       0.000527
# min     0.001290       0.001672
# 25%     0.001527       0.001858
# 50%     0.001752       0.001975
# 75%     0.002211       0.002329
# max     0.002856       0.004062
