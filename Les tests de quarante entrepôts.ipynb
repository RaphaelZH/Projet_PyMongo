# %% [markdown]
# # Préparation

# %% [markdown]
# ## Installation des packages

# %%
import pymongo
from pymongo import MongoClient
import random
import datetime
from time import process_time
from pandas.core.frame import DataFrame

# %% [markdown]
# ## Connexion à la base de données

# %%
client = MongoClient(host="localhost", port=27017)
db = client["40_Warehouses"]

# %% [markdown]
# ## Accès des collections

# %%
Customer_40 = db["Customer_40"]
Order_40 = db["Order_40"]
Order_Line_40 = db["Order_Line_40"]
Semi_40 = db["Semi_40"]
Denormal_40 = db["Denormal_40"]

# %% [markdown]
# ## Création des variables aléatoires

# %%
district = str(random.randint(1, 10))
warehouse = str(random.randint(1, 40))
customer = str(random.randint(1, 3000))
daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# %% [markdown]
# # La requête C,  créer dix articles à une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
C_40_normal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_40.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1"
    })

    Order_Line_40.insert_many([{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "2",
                                   "ol_i_id": "785",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "7",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "3",
                                   "ol_i_id": "712",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "4",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "4",
                                   "ol_i_id": "1257",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "8",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "5",
                                   "ol_i_id": "2568",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "2",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "6",
                                   "ol_i_id": "6287",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "9",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "7",
                                   "ol_i_id": "7788",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "3",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "8",
                                   "ol_i_id": "5589",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "6",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "9",
                                   "ol_i_id": "5589",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "6",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                               },
                               {
                                   "ol_id": str(j),
                                   "ol_d_id": district,
                                   "ol_w_id": warehouse,
                                   "ol_number": "10",
                                   "ol_i_id": "5589",
                                   "ol_supply_w_id": "1",
                                   "ol_delivery_d": daytime,
                                   "ol_quantity": "6",
                                   "ol_amount": "28.45",
                                   "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                               }])
    end = process_time()
    time = end - start
    C_40_normal.append(time)
    i += 1
    j += 1
print(C_40_normal)
# Out:
# [0.003273999999999777, 0.002653999999999712, 0.0036839999999997985, 0.0015100000000001224, 0.0015339999999999243, 0.0014420000000003874, 0.0016859999999998543, 0.002017999999999631, 0.0014759999999998108, 0.0014899999999999913, 0.0014780000000000904, 0.0019739999999996982, 0.0019860000000000433, 0.0016039999999999388, 0.0021179999999998422, 0.0018280000000001628, 0.0014439999999997788, 0.0014379999999998283, 0.0014639999999999098, 0.0014699999999998603]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
C_40_semi = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    order_lines = [{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "2",
                       "ol_i_id": "785",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "7",
                       "ol_amount": "28.45",
                       "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "3",
                       "ol_i_id": "712",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "4",
                       "ol_amount": "28.45",
                       "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "4",
                       "ol_i_id": "1257",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "8",
                       "ol_amount": "28.45",
                       "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "5",
                       "ol_i_id": "2568",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "2",
                       "ol_amount": "28.45",
                       "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "6",
                       "ol_i_id": "6287",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "9",
                       "ol_amount": "28.45",
                       "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "7",
                       "ol_i_id": "7788",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "3",
                       "ol_amount": "28.45",
                       "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "8",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "9",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "10",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                   }]

    Semi_40.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    })
    end = process_time()
    time = end - start
    C_40_semi.append(time)
    i += 1
    j += 1
print(C_40_semi)
# Out:
# [0.0013600000000000279, 0.000892000000000337, 0.0010780000000001344, 0.0008179999999997634, 0.0006819999999998494, 0.0006779999999997344, 0.0006820000000002935, 0.000656000000000212, 0.0006639999999999979, 0.000716000000000161, 0.0007559999999999789, 0.0007540000000001434, 0.0009060000000000734, 0.0006979999999998654, 0.0006800000000000139, 0.0006800000000000139, 0.0006819999999998494, 0.0006800000000000139, 0.0008060000000003065, 0.0011139999999998373]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
C_40_denormal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_Info = Denormal_40.find_one({
        "$and": [{
            "c_id": customer
        }, {
            "c_d_id": district
        }, {
            "c_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "c_first": 1,
        "c_middle": 1,
        "c_last": 1,
        "c_street_1": 1,
        "c_street_2": 1,
        "c_city": 1,
        "c_state": 1,
        "c_zip": 1,
        "c_phone": 1,
        "c_since": 1,
        "c_credit": 1,
        "c_credit_lim": 1,
        "c_discount": 1,
        "c_balance": 1,
        "c_ytd_payment": 1,
        "c_payment_cnt": 1,
        "c_delivery_cnt": 1,
        "c_data": 1
    })
    customer_order = [{
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    }]

    Denormal_40.update_one({
        "c_id": customer,
        "c_d_id": district,
        "c_w_id": warehouse
    }, {
        "$set": {
            "c_first": Customer_Info.get("c_first"),
            "c_middle": Customer_Info.get("c_middle"),
            "c_last": Customer_Info.get("c_last"),
            "c_street_1": Customer_Info.get("c_street_1"),
            "c_street_2": Customer_Info.get("c_street_2"),
            "c_city": Customer_Info.get("c_city"),
            "c_state": Customer_Info.get("c_state"),
            "c_zip": Customer_Info.get("c_zip"),
            "c_phone": Customer_Info.get("c_phone"),
            "c_since": Customer_Info.get("c_since"),
            "c_credit": Customer_Info.get("c_credit"),
            "c_credit_lim": Customer_Info.get("c_credit_lim"),
            "c_discount": Customer_Info.get("c_first"),
            "c_balance": Customer_Info.get("c_balance"),
            "c_ytd_payment": Customer_Info.get("c_ytd_payment"),
            "c_payment_cnt": Customer_Info.get("c_payment_cnt"),
            "c_delivery_cnt": Customer_Info.get("c_delivery_cnt"),
            "c_data": Customer_Info.get("c_data"),
            "customer_order": customer_order
        }
    },
                           upsert=True)
    end = process_time()
    time = end - start
    C_40_denormal.append(time)
    i += 1
    j += 1
print(C_40_denormal)
# Out:
# [0.0033639999999999226, 0.0019439999999999458, 0.0015340000000003684, 0.0016000000000002679, 0.0018359999999999488, 0.0014719999999996958, 0.0013540000000000774, 0.0018579999999999153, 0.0015300000000002534, 0.0014300000000000423, 0.0015080000000002869, 0.0015520000000002199, 0.0015860000000000873, 0.0014199999999999768, 0.0019320000000000448, 0.0015819999999999723, 0.0018259999999998833, 0.0015020000000003364, 0.0015179999999999083, 0.0015879999999999228]

# %% [markdown]
# # La requête R, chercher aléatoirement l’information d’un client

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
R_40_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_40.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Order_40.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_40_normal.append(time)
    i += 1
print(R_40_normal)
# Out:
# [0.010352000000000139, 0.0027240000000001707, 0.0017580000000001483, 0.0017260000000001163, 0.0017480000000000828, 0.0016979999999997553, 0.0015640000000001208, 0.0014380000000002724, 0.0016519999999999868, 0.0014080000000000759, 0.0014180000000001414, 0.0022739999999998872, 0.0016279999999997408, 0.0018340000000001133, 0.0015119999999999578, 0.0017380000000000173, 0.0015600000000000058, 0.0018340000000001133, 0.0015499999999999403, 0.0015559999999998908]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
R_40_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_40.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Semi_40.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_40_semi.append(time)
    i += 1
print(R_40_semi)
# Out:
# [0.0028880000000000017, 0.0016780000000000683, 0.0017380000000000173, 0.0015499999999999403, 0.0015600000000000058, 0.0016199999999999548, 0.0021659999999998902, 0.0015800000000001369, 0.0018139999999999823, 0.0017220000000000013, 0.0017340000000003464, 0.0022020000000000373, 0.0017179999999998863, 0.0018839999999999968, 0.0015700000000000713, 0.0016639999999998878, 0.0015239999999998588, 0.0016359999999999708, 0.0015139999999997933, 0.0015240000000003029]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
R_40_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_40.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })
    Denormal_40.aggregate([{
        "$match": {
            "$and": [{
                "c_id": Customer_id.get("c_id")
            }, {
                "c_d_id": Customer_id.get("c_d_id")
            }, {
                "c_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "customer_order.o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "customer_order.o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_40_denormal.append(time)
    i += 1
print(R_40_denormal)
# Out:
# [0.0026320000000001897, 0.0016619999999996082, 0.0014039999999999608, 0.0014579999999999593, 0.0016340000000001353, 0.0015040000000001719, 0.0017119999999999358, 0.0015860000000000873, 0.0017879999999999008, 0.0016020000000001033, 0.0018180000000000973, 0.0015800000000001369, 0.0015340000000003684, 0.002097999999999711, 0.0014240000000000919, 0.0016660000000001673, 0.0013899999999997803, 0.0015320000000000888, 0.0014280000000002069, 0.0015719999999999068]

# %% [markdown]
# # La requête U, modifier le temps de livraison des dix articles

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
U_40_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Order_Line_40.find_one_and_update({
            "ol_delivery_d": None
        }, {"$set": {
            "ol_delivery_d": daytime
        }},
                                          sort=[("ol_id", pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_40_normal.append(time)
    i += 1
print(U_40_normal)
# Out:
# [0.041981999999999964, 0.024602000000000235, 0.024950000000000028, 0.02522000000000002, 0.02507400000000004, 0.027292000000000094, 0.03159000000000001, 0.03264599999999973, 0.030090000000000394, 0.029510000000000147, 0.026759999999999895, 0.0257780000000003, 0.026098000000000177, 0.02659199999999995, 0.026072000000000095, 0.02760600000000002, 0.02621600000000024, 0.02731799999999973, 0.02629999999999999, 0.02688999999999986]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
U_40_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Semi_40.find_one_and_update({
            "order_lines.ol_delivery_d": None
        }, {"$set": {
            "order_lines.$.ol_delivery_d": daytime
        }},
                                    sort=[("order_lines.ol_id",
                                           pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_40_semi.append(time)
    i += 1
print(U_40_semi)
# Out:
# [0.08733999999999975, 0.04583199999999987, 0.03731600000000013, 0.03401999999999994, 0.03395799999999971, 0.033090000000000064, 0.03442600000000029, 0.036362000000000005, 0.03417799999999982, 0.03344999999999976, 0.03232400000000002, 0.03397799999999984, 0.03313599999999983, 0.0320159999999996, 0.03325400000000034, 0.03515200000000007, 0.03176200000000007, 0.032976000000000116, 0.03215799999999991, 0.03229400000000027]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
U_40_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Denormal_40.find_one_and_update(
            {
                "customer_order.order_lines.ol_delivery_d": None
            }, {
                "$set": {
                    "customer_order.0.order_lines.1.ol_delivery_d": daytime
                }
            },
            sort=[("customer_order.order_lines.ol_id", pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_40_denormal.append(time)
    i += 1
print(U_40_denormal)
# Out:
# [0.1919960000000005, 0.14313399999999987, 0.13444000000000056, 0.1448419999999997, 0.14466, 0.13689400000000074, 0.1376759999999999, 0.14579399999999954, 0.1460240000000006, 0.1458320000000004, 0.1415160000000002, 0.14135600000000004, 0.14439400000000013, 0.1389080000000007, 0.14266000000000023, 0.14508399999999977, 0.14015800000000045, 0.1708059999999998, 0.16150600000000015, 0.1729919999999998]

# %% [markdown]
# # La requête D, supprimer aléatoirement d’une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
D_40_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_40.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Order_40.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    Order_40.delete_many({
        "$and": [{
            "ol_id": Order_Line_Info.get("ol_id")
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_40_normal.append(time)
    i += 1
print(D_40_normal)
# Out:
# [0.010626000000000246, 0.0032240000000003377, 0.003117999999999732, 0.0030519999999993885, 0.0033080000000005327, 0.0030540000000005563, 0.003918000000000532, 0.003193999999999697, 0.0026100000000006673, 0.0030960000000002097, 0.002801999999999971, 0.0029599999999998516, 0.0029900000000004923, 0.0030440000000000467, 0.0032260000000006173, 0.0028740000000002652, 0.003762000000000043, 0.002969999999999473, 0.0032839999999998426, 0.00326200000000032]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
D_40_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_40.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Semi_40.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_40_semi.append(time)
    i += 1
print(D_40_semi)
# Out:
# [0.005234000000000627, 0.0020980000000001553, 0.0020780000000000243, 0.0020899999999999253, 0.0018979999999997332, 0.001972000000000307, 0.0017979999999999663, 0.0017680000000002138, 0.0018299999999999983, 0.0017379999999995732, 0.001972000000000307, 0.0021180000000002863, 0.0017319999999996227, 0.0021919999999999717, 0.0029719999999997526, 0.001960000000000406, 0.0021659999999998902, 0.0019780000000002573, 0.0018120000000001468, 0.0016420000000003654]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
D_40_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 40))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_40.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Denormal_40.update_one(
        {
            "customer_order.o_id": Order_Line_Info.get("ol_id"),
            "customer_order.o_d_id": district,
            "customer_order.o_w_id": warehouse
        }, {
            "$unset": {
                "customer_order._id": "",
                "customer_order.o_id": "",
                "customer_order.o_d_id": "",
                "customer_order.o_w_id": "",
                "customer_order.o_c_id": "",
                "customer_order.o_entry_d": "",
                "customer_order.o_carrier_id": "",
                "customer_order.o_ol_cnt": "",
                "customer_order.o_all_local": "",
                "customer_order.order_lines": ""
            }
        },
        upsert=True)
    end = process_time()
    time = end - start
    D_40_denormal.append(time)
    i += 1
print(D_40_denormal)
# Out:
# [0.011838000000000015, 0.007821999999999996, 0.005978000000000705, 0.00589400000000051, 0.0028880000000004458, 0.004458000000000517, 0.0030140000000002942, 0.0035440000000006577, 0.0028820000000004953, 0.0028280000000000527, 0.005250000000000199, 0.0041359999999999175, 0.003505999999999787, 0.003454000000000512, 0.0033199999999995455, 0.0039959999999998885, 0.0027140000000001052, 0.0026860000000006323, 0.002673999999999843, 0.003274000000000221]

# %%
dic = {
    "C_40_normal": C_40_normal,
    "C_40_semi": C_40_semi,
    "C_40_denormal": C_40_denormal,
    "R_40_normal": R_40_normal,
    "R_40_semi": R_40_semi,
    "R_40_denormal": R_40_denormal,
    "U_40_normal": U_40_normal,
    "U_40_semi": U_40_semi,
    "U_40_denormal": U_40_denormal,
    "D_40_normal": D_40_normal,
    "D_40_semi": D_40_semi,
    "D_40_denormal": D_40_denormal
}

# %%
df = DataFrame(dic)
print(df)
# Out:
#     C_40_normal  C_40_semi  C_40_denormal  R_40_normal  R_40_semi  \
# 0      0.003274   0.001360       0.003364     0.010352   0.002888
# 1      0.002654   0.000892       0.001944     0.002724   0.001678
# 2      0.003684   0.001078       0.001534     0.001758   0.001738
# 3      0.001510   0.000818       0.001600     0.001726   0.001550
# 4      0.001534   0.000682       0.001836     0.001748   0.001560
# 5      0.001442   0.000678       0.001472     0.001698   0.001620
# 6      0.001686   0.000682       0.001354     0.001564   0.002166
# 7      0.002018   0.000656       0.001858     0.001438   0.001580
# 8      0.001476   0.000664       0.001530     0.001652   0.001814
# 9      0.001490   0.000716       0.001430     0.001408   0.001722
# 10     0.001478   0.000756       0.001508     0.001418   0.001734
# 11     0.001974   0.000754       0.001552     0.002274   0.002202
# 12     0.001986   0.000906       0.001586     0.001628   0.001718
# 13     0.001604   0.000698       0.001420     0.001834   0.001884
# 14     0.002118   0.000680       0.001932     0.001512   0.001570
# 15     0.001828   0.000680       0.001582     0.001738   0.001664
# 16     0.001444   0.000682       0.001826     0.001560   0.001524
# 17     0.001438   0.000680       0.001502     0.001834   0.001636
# 18     0.001464   0.000806       0.001518     0.001550   0.001514
# 19     0.001470   0.001114       0.001588     0.001556   0.001524
#
#     R_40_denormal  U_40_normal  U_40_semi  U_40_denormal  D_40_normal  \
# 0        0.002632     0.041982   0.087340       0.191996     0.010626
# 1        0.001662     0.024602   0.045832       0.143134     0.003224
# 2        0.001404     0.024950   0.037316       0.134440     0.003118
# 3        0.001458     0.025220   0.034020       0.144842     0.003052
# 4        0.001634     0.025074   0.033958       0.144660     0.003308
# 5        0.001504     0.027292   0.033090       0.136894     0.003054
# 6        0.001712     0.031590   0.034426       0.137676     0.003918
# 7        0.001586     0.032646   0.036362       0.145794     0.003194
# 8        0.001788     0.030090   0.034178       0.146024     0.002610
# 9        0.001602     0.029510   0.033450       0.145832     0.003096
# 10       0.001818     0.026760   0.032324       0.141516     0.002802
# 11       0.001580     0.025778   0.033978       0.141356     0.002960
# 12       0.001534     0.026098   0.033136       0.144394     0.002990
# 13       0.002098     0.026592   0.032016       0.138908     0.003044
# 14       0.001424     0.026072   0.033254       0.142660     0.003226
# 15       0.001666     0.027606   0.035152       0.145084     0.002874
# 16       0.001390     0.026216   0.031762       0.140158     0.003762
# 17       0.001532     0.027318   0.032976       0.170806     0.002970
# 18       0.001428     0.026300   0.032158       0.161506     0.003284
# 19       0.001572     0.026890   0.032294       0.172992     0.003262
#
#     D_40_semi  D_40_denormal
# 0    0.005234       0.011838
# 1    0.002098       0.007822
# 2    0.002078       0.005978
# 3    0.002090       0.005894
# 4    0.001898       0.002888
# 5    0.001972       0.004458
# 6    0.001798       0.003014
# 7    0.001768       0.003544
# 8    0.001830       0.002882
# 9    0.001738       0.002828
# 10   0.001972       0.005250
# 11   0.002118       0.004136
# 12   0.001732       0.003506
# 13   0.002192       0.003454
# 14   0.002972       0.003320
# 15   0.001960       0.003996
# 16   0.002166       0.002714
# 17   0.001978       0.002686
# 18   0.001812       0.002674
# 19   0.001642       0.003274

# %%
df.to_csv("tests_40.csv", index=False, sep=',')

# %%
df.describe()
# Out:
#        C_40_normal  C_40_semi  C_40_denormal  R_40_normal  R_40_semi  \
# count    20.000000  20.000000      20.000000    20.000000  20.000000
# mean      0.001879   0.000799       0.001697     0.002149   0.001764
# std       0.000635   0.000188       0.000429     0.001955   0.000327
# min       0.001438   0.000656       0.001354     0.001408   0.001514
# 25%       0.001474   0.000680       0.001507     0.001554   0.001568
# 50%       0.001569   0.000707       0.001567     0.001675   0.001671
# 75%       0.001994   0.000836       0.001828     0.001777   0.001757
# max       0.003684   0.001360       0.003364     0.010352   0.002888
#
#        R_40_denormal  U_40_normal  U_40_semi  U_40_denormal  D_40_normal  \
# count      20.000000    20.000000  20.000000      20.000000    20.000000
# mean        0.001651     0.027929   0.036951       0.148534     0.003519
# std         0.000285     0.003960   0.012249       0.014527     0.001699
# min         0.001390     0.024602   0.031762       0.134440     0.002610
# 25%         0.001493     0.025999   0.032813       0.141057     0.002985
# 50%         0.001583     0.026676   0.033704       0.144527     0.003107
# 75%         0.001678     0.028082   0.034608       0.145880     0.003268
# max         0.002632     0.041982   0.087340       0.191996     0.010626
#
#        D_40_semi  D_40_denormal
# count  20.000000      20.000000
# mean    0.002152       0.004308
# std     0.000777       0.002238
# min     0.001642       0.002674
# 25%     0.001809       0.002887
# 50%     0.001972       0.003480
# 75%     0.002103       0.004656
# max     0.005234       0.011838
