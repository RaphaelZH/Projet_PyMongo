# %% [markdown]
# # Préparation

# %% [markdown]
# ## Installation des packages

# %%
import pymongo
from pymongo import MongoClient
import random
import datetime
from time import process_time
from pandas.core.frame import DataFrame

# %% [markdown]
# ## Connexion à la base de données

# %%
client = MongoClient(host="localhost", port=27017)
db = client["20_Warehouses"]

# %% [markdown]
# ## Accès des collections

# %%
Customer_20 = db["Customer_20"]
Order_20 = db["Order_20"]
Order_Line_20 = db["Order_Line_20"]
Semi_20 = db["Semi_20"]
Denormal_20 = db["Denormal_20"]

# %% [markdown]
# ## Création des variables aléatoires

# %%
district = str(random.randint(1, 10))
warehouse = str(random.randint(1, 20))
customer = str(random.randint(1, 3000))
daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))

# %% [markdown]
# # La requête C,  créer dix articles à une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
C_20_normal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_20.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1"
    })

    Order_Line_20.insert_many([{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "2",
                                  "ol_i_id": "785",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "7",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "3",
                                  "ol_i_id": "712",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "4",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "4",
                                  "ol_i_id": "1257",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "8",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "5",
                                  "ol_i_id": "2568",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "2",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "6",
                                  "ol_i_id": "6287",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "9",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "7",
                                  "ol_i_id": "7788",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "3",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "8",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "9",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                              },
                              {
                                  "ol_id": str(j),
                                  "ol_d_id": district,
                                  "ol_w_id": warehouse,
                                  "ol_number": "10",
                                  "ol_i_id": "5589",
                                  "ol_supply_w_id": "1",
                                  "ol_delivery_d": daytime,
                                  "ol_quantity": "6",
                                  "ol_amount": "28.45",
                                  "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                              }])
    end = process_time()
    time = end - start
    C_20_normal.append(time)
    i += 1
    j += 1
print(C_20_normal)
# Out:
# [0.003105999999999831, 0.0015300000000002534, 0.0014699999999998603, 0.0015819999999999723, 0.0012780000000001124, 0.0012159999999998838, 0.0012900000000000134, 0.0013580000000001924, 0.0013739999999997643, 0.001496000000000386, 0.0016400000000000858, 0.0014300000000000423, 0.0013899999999997803, 0.0013159999999996508, 0.001264000000000376, 0.0012499999999997513, 0.0013760000000000439, 0.001228000000000229, 0.0012520000000000309, 0.0014380000000002724]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
C_20_semi = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    order_lines = [{
        "ol_id": str(j),
        "ol_d_id": district,
        "ol_w_id": warehouse,
        "ol_number": "1",
        "ol_i_id": "18",
        "ol_supply_w_id": "1",
        "ol_delivery_d": daytime,
        "ol_quantity": "5",
        "ol_amount": "28.45",
        "ol_dist_info": "iEzgA7QwZd8gUinzlkVdiNpr"
    },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "2",
                       "ol_i_id": "785",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "7",
                       "ol_amount": "28.45",
                       "ol_dist_info": "cEheMfYt4oYQPe4ePeSYxPyo"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "3",
                       "ol_i_id": "712",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "4",
                       "ol_amount": "28.45",
                       "ol_dist_info": "rh69x6pYBJoyh3qh8KvgkhvG"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "4",
                       "ol_i_id": "1257",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "8",
                       "ol_amount": "28.45",
                       "ol_dist_info": "XLdieGnVNMnw1AJhLGC1pz1N"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "5",
                       "ol_i_id": "2568",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "2",
                       "ol_amount": "28.45",
                       "ol_dist_info": "gNwgQuvSwWeH9CJOVzAl5acI"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "6",
                       "ol_i_id": "6287",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "9",
                       "ol_amount": "28.45",
                       "ol_dist_info": "MPdoCJRthh7v23wquKgczPhX"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "7",
                       "ol_i_id": "7788",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "3",
                       "ol_amount": "28.45",
                       "ol_dist_info": "vvrxoFgnYeELo8UKoXrqiY74"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "8",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "IUvpqUG98e2S3oIrXu1qMUz3"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "9",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "0mQUiEfHxt9Jf4TyfzDg2dWk"
                   },
                   {
                       "ol_id": str(j),
                       "ol_d_id": district,
                       "ol_w_id": warehouse,
                       "ol_number": "10",
                       "ol_i_id": "5589",
                       "ol_supply_w_id": "1",
                       "ol_delivery_d": daytime,
                       "ol_quantity": "6",
                       "ol_amount": "28.45",
                       "ol_dist_info": "4UcMfc5X7Tm6HBNWM26eobeh"
                   }]

    Semi_20.insert_one({
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    })
    end = process_time()
    time = end - start
    C_20_semi.append(time)
    i += 1
    j += 1
print(C_20_semi)
# Out:
# [0.0013420000000001764, 0.0007379999999996834, 0.0007220000000001114, 0.0007299999999998974, 0.000732000000000177, 0.0007340000000000124, 0.0008059999999998624, 0.0007760000000001099, 0.0009579999999997924, 0.0007859999999997314, 0.0010059999999998404, 0.0010559999999997238, 0.0010220000000003004, 0.0009100000000001884, 0.0009039999999997939, 0.0009159999999996948, 0.0009600000000000719, 0.0007619999999999294, 0.0007299999999998974, 0.000732000000000177]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
C_20_denormal = []
i = 0
j = 4001
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_Info = Denormal_20.find_one({
        "$and": [{
            "c_id": customer
        }, {
            "c_d_id": district
        }, {
            "c_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "c_first": 1,
        "c_middle": 1,
        "c_last": 1,
        "c_street_1": 1,
        "c_street_2": 1,
        "c_city": 1,
        "c_state": 1,
        "c_zip": 1,
        "c_phone": 1,
        "c_since": 1,
        "c_credit": 1,
        "c_credit_lim": 1,
        "c_discount": 1,
        "c_balance": 1,
        "c_ytd_payment": 1,
        "c_payment_cnt": 1,
        "c_delivery_cnt": 1,
        "c_data": 1
    })
    customer_order = [{
        "o_id": str(j),
        "o_d_id": district,
        "o_w_id": warehouse,
        "o_c_id": customer,
        "o_entry_d": daytime,
        "o_carrier_id": "4",
        "o_ol_cnt": "10",
        "o_all_local": "1",
        "order_lines": order_lines
    }]

    Denormal_20.update_one({
        "c_id": customer,
        "c_d_id": district,
        "c_w_id": warehouse
    }, {
        "$set": {
            "c_first": Customer_Info.get("c_first"),
            "c_middle": Customer_Info.get("c_middle"),
            "c_last": Customer_Info.get("c_last"),
            "c_street_1": Customer_Info.get("c_street_1"),
            "c_street_2": Customer_Info.get("c_street_2"),
            "c_city": Customer_Info.get("c_city"),
            "c_state": Customer_Info.get("c_state"),
            "c_zip": Customer_Info.get("c_zip"),
            "c_phone": Customer_Info.get("c_phone"),
            "c_since": Customer_Info.get("c_since"),
            "c_credit": Customer_Info.get("c_credit"),
            "c_credit_lim": Customer_Info.get("c_credit_lim"),
            "c_discount": Customer_Info.get("c_first"),
            "c_balance": Customer_Info.get("c_balance"),
            "c_ytd_payment": Customer_Info.get("c_ytd_payment"),
            "c_payment_cnt": Customer_Info.get("c_payment_cnt"),
            "c_delivery_cnt": Customer_Info.get("c_delivery_cnt"),
            "c_data": Customer_Info.get("c_data"),
            "customer_order": customer_order
        }
    },
                          upsert=True)
    end = process_time()
    time = end - start
    C_20_denormal.append(time)
    i += 1
    j += 1
print(C_20_denormal)
# Out:
# [0.0031260000000004062, 0.0021100000000000563, 0.0022079999999999878, 0.002048000000000272, 0.0016120000000001689, 0.0016220000000002344, 0.0018240000000000478, 0.0017160000000000508, 0.0016119999999997248, 0.0015079999999998428, 0.0016039999999999388, 0.0015580000000001704, 0.0015520000000002199, 0.0013939999999998953, 0.0016659999999997233, 0.0017999999999998018, 0.0017800000000001148, 0.0017100000000001003, 0.0015600000000000058, 0.0015819999999999723]

# %% [markdown]
# # La requête R, chercher aléatoirement l’information d’un client

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
R_20_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_20.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Order_20.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_20_normal.append(time)
    i += 1
print(R_20_normal)
# Out:
# [0.008637999999999924, 0.0018500000000001293, 0.0014500000000001734, 0.0016220000000002344, 0.0028800000000002157, 0.002726000000000006, 0.0017360000000001818, 0.002413999999999916, 0.0015020000000003364, 0.0017399999999998528, 0.0015100000000001224, 0.0018080000000000318, 0.0016180000000001193, 0.0014199999999999768, 0.0018259999999998833, 0.0013819999999999943, 0.0017079999999998208, 0.0015320000000000888, 0.0014759999999998108, 0.0013480000000001269]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
R_20_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_20.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })

    Semi_20.aggregate([{
        "$match": {
            "$and": [{
                "o_c_id": Customer_id.get("c_id")
            }, {
                "o_d_id": Customer_id.get("c_d_id")
            }, {
                "o_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_20_semi.append(time)
    i += 1
print(R_20_semi)
# Out:
# [0.003617999999999899, 0.0018260000000003274, 0.0013760000000000439, 0.0013899999999997803, 0.0013399999999998968, 0.0014879999999997118, 0.0013819999999999943, 0.0013260000000001604, 0.0014199999999999768, 0.0013860000000001094, 0.0013939999999998953, 0.0013799999999997148, 0.0014060000000002404, 0.0013659999999999783, 0.0014620000000000744, 0.0014020000000001254, 0.0012579999999999814, 0.0014720000000001399, 0.0013679999999998138, 0.0013980000000000103]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
R_20_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Customer_id = Customer_20.find_one({
        "$and": [{
            "c_first": Customer_Info.get("c_first")
        }, {
            "c_last": Customer_Info.get("c_last")
        }]
    }, {
        "_id": 0,
        "c_id": 1,
        "c_d_id": 1,
        "c_w_id": 1
    })
    Denormal_20.aggregate([{
        "$match": {
            "$and": [{
                "c_id": Customer_id.get("c_id")
            }, {
                "c_d_id": Customer_id.get("c_d_id")
            }, {
                "c_w_id": Customer_id.get("c_w_id")
            }]
        }
    }, {
        "$sort": {
            "customer_order.o_entry_d": -1
        }
    }, {
        "$limit": 1
    }, {
        "$project": {
            "_id": 0,
            "customer_order.o_id": 1
        }
    }])
    end = process_time()
    time = end - start
    R_20_denormal.append(time)
    i += 1
print(R_20_denormal)
# Out:
# [0.004258000000000095, 0.0015620000000002854, 0.0015499999999999403, 0.0015719999999999068, 0.0021119999999998917, 0.0021300000000001873, 0.0016780000000000683, 0.0017239999999998368, 0.0014199999999999768, 0.0015900000000002024, 0.0015679999999997918, 0.0014179999999996973, 0.0015079999999998428, 0.0015100000000001224, 0.0015179999999999083, 0.0016380000000002504, 0.0014680000000000248, 0.0019459999999997812, 0.0026159999999997297, 0.0014459999999996143]

# %% [markdown]
# # La requête U, modifier le temps de livraison des dix articles

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
U_20_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Order_Line_20.find_one_and_update({
            "ol_delivery_d": None
        }, {"$set": {
            "ol_delivery_d": daytime
        }},
                                         sort=[("ol_id", pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_20_normal.append(time)
    i += 1
print(U_20_normal)
# Out:
# [0.026637999999999717, 0.01958800000000016, 0.018403999999999865, 0.017684000000000033, 0.020917999999999992, 0.016415999999999986, 0.017166000000000015, 0.020286000000000026, 0.018993999999999733, 0.01757799999999987, 0.019757999999999942, 0.01986399999999966, 0.018438000000000176, 0.021455999999999698, 0.019703999999999944, 0.017724000000000295, 0.018888000000000016, 0.018120000000000136, 0.01967400000000019, 0.016360000000000152]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
U_20_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Semi_20.find_one_and_update({
            "order_lines.ol_delivery_d": None
        }, {"$set": {
            "order_lines.$.ol_delivery_d": daytime
        }},
                                   sort=[("order_lines.ol_id",
                                          pymongo.ASCENDING)])
        j += 1
    end = process_time()
    time = end - start
    U_20_semi.append(time)
    i += 1
print(U_20_semi)
# Out:
# [0.04117000000000015, 0.02459599999999984, 0.02127800000000013, 0.020594, 0.020804000000000045, 0.02165399999999984, 0.021328000000000014, 0.020678000000000196, 0.0242119999999999, 0.01924400000000004, 0.022858000000000267, 0.02074200000000026, 0.020331999999999795, 0.020265999999999895, 0.02249599999999985, 0.020202000000000275, 0.01933000000000007, 0.020767999999999898, 0.02096399999999976, 0.020295999999999648]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
U_20_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    j = 0
    for j in range(10):
        Denormal_20.find_one_and_update({
            "customer_order.order_lines.ol_delivery_d":
            None
        }, {"$set": {
            "customer_order.0.order_lines.1.ol_delivery_d": daytime
        }},
                                       sort=[
                                           ("customer_order.order_lines.ol_id",
                                            pymongo.ASCENDING)
                                       ])
        j += 1
    end = process_time()
    time = end - start
    U_20_denormal.append(time)
    i += 1
print(U_20_denormal)
# Out:
# [0.0788660000000001, 0.02939000000000025, 0.02542999999999962, 0.024983999999999895, 0.026152000000000175, 0.026184000000000207, 0.025387999999999966, 0.027973999999999943, 0.022837999999999692, 0.02270799999999973, 0.02679200000000037, 0.02516600000000002, 0.03080399999999983, 0.026293999999999595, 0.02845600000000026, 0.02397599999999933, 0.02474399999999921, 0.02179999999999982, 0.025054000000000798, 0.02490600000000054]

# %% [markdown]
# # La requête D, supprimer aléatoirement d’une commande

# %% [markdown]
# ## Sur un groupe de collections de normalisation

# %%
D_20_normal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_20.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Order_20.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    Order_20.delete_many({
        "$and": [{
            "ol_id": Order_Line_Info.get("ol_id")
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_20_normal.append(time)
    i += 1
print(D_20_normal)
# Out:
# [0.0059840000000006555, 0.002729999999999677, 0.002733999999999348, 0.0030120000000000147, 0.0031959999999999766, 0.003169999999999895, 0.0023820000000007724, 0.0033159999999998746, 0.002417999999999587, 0.002589999999999648, 0.002841999999999345, 0.0049960000000002225, 0.003122000000000291, 0.0036480000000000956, 0.0030799999999997496, 0.0024980000000001112, 0.0025759999999994676, 0.0028920000000001167, 0.0028079999999999217, 0.004229999999999734]

# %% [markdown]
# ## Sur une collection de semi-dénormalisation

# %%
D_20_semi = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_20.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Semi_20.delete_one({
        "$and": [{
            "o_id": Order_Line_Info.get("ol_id")
        }, {
            "o_d_id": district
        }, {
            "o_w_id": warehouse
        }]
    })
    end = process_time()
    time = end - start
    D_20_semi.append(time)
    i += 1
print(D_20_semi)
# Out:
# [0.0037000000000002586, 0.0017979999999999663, 0.0018860000000007204, 0.0017740000000001643, 0.0016020000000001033, 0.0014599999999997948, 0.0018260000000003274, 0.0013579999999997483, 0.001604000000000383, 0.0022120000000001028, 0.0017499999999994742, 0.0015780000000003014, 0.0018039999999999168, 0.0016239999999996257, 0.0018620000000000303, 0.0018359999999999488, 0.0017819999999995062, 0.0017260000000005604, 0.0017279999999999518, 0.0019340000000003243]

# %% [markdown]
# ## Sur une collection de dénormalisation

# %%
D_20_denormal = []
i = 0
for i in range(20):
    start = process_time()
    district = str(random.randint(1, 10))
    warehouse = str(random.randint(1, 20))
    customer = str(random.randint(1, 3000))
    daytime = str(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    Order_Line_Info = Order_Line_20.find_one({
        "$and": [{
            "ol_delivery_d": None
        }, {
            "ol_d_id": district
        }, {
            "ol_w_id": warehouse
        }]
    }, {
        "_id": 0,
        "ol_id": 1
    })
    Denormal_20.update_one({
        "customer_order.o_id": Order_Line_Info.get("ol_id"),
        "customer_order.o_d_id": district,
        "customer_order.o_w_id": warehouse
    }, {
        "$unset": {
            "customer_order._id": "",
            "customer_order.o_id": "",
            "customer_order.o_d_id": "",
            "customer_order.o_w_id": "",
            "customer_order.o_c_id": "",
            "customer_order.o_entry_d": "",
            "customer_order.o_carrier_id": "",
            "customer_order.o_ol_cnt": "",
            "customer_order.o_all_local": "",
            "customer_order.order_lines": ""
        }
    },
                          upsert=True)
    end = process_time()
    time = end - start
    D_20_denormal.append(time)
    i += 1
print(D_20_denormal)
# Out:
# [0.007488000000000383, 0.002201999999999593, 0.002365999999999424, 0.0020579999999998932, 0.0032399999999999096, 0.0019799999999996487, 0.002160000000000828, 0.002501999999999782, 0.002181999999999462, 0.0019580000000001263, 0.0022279999999996747, 0.0028719999999999857, 0.002169999999999561, 0.0019260000000000943, 0.0018640000000003099, 0.0018099999999998673, 0.001956000000000735, 0.002424000000000426, 0.0021399999999998087, 0.0016639999999998878]

# %%
dic = {
    "C_20_normal": C_20_normal,
    "C_20_semi": C_20_semi,
    "C_20_denormal": C_20_denormal,
    "R_20_normal": R_20_normal,
    "R_20_semi": R_20_semi,
    "R_20_denormal": R_20_denormal,
    "U_20_normal": U_20_normal,
    "U_20_semi": U_20_semi,
    "U_20_denormal": U_20_denormal,
    "D_20_normal": D_20_normal,
    "D_20_semi": D_20_semi,
    "D_20_denormal": D_20_denormal
}

# %%
df = DataFrame(dic)
print(df)
# Out:
#     C_20_normal  C_20_semi  C_20_denormal  R_20_normal  R_20_semi  \
# 0      0.003106   0.001342       0.003126     0.008638   0.003618
# 1      0.001530   0.000738       0.002110     0.001850   0.001826
# 2      0.001470   0.000722       0.002208     0.001450   0.001376
# 3      0.001582   0.000730       0.002048     0.001622   0.001390
# 4      0.001278   0.000732       0.001612     0.002880   0.001340
# 5      0.001216   0.000734       0.001622     0.002726   0.001488
# 6      0.001290   0.000806       0.001824     0.001736   0.001382
# 7      0.001358   0.000776       0.001716     0.002414   0.001326
# 8      0.001374   0.000958       0.001612     0.001502   0.001420
# 9      0.001496   0.000786       0.001508     0.001740   0.001386
# 10     0.001640   0.001006       0.001604     0.001510   0.001394
# 11     0.001430   0.001056       0.001558     0.001808   0.001380
# 12     0.001390   0.001022       0.001552     0.001618   0.001406
# 13     0.001316   0.000910       0.001394     0.001420   0.001366
# 14     0.001264   0.000904       0.001666     0.001826   0.001462
# 15     0.001250   0.000916       0.001800     0.001382   0.001402
# 16     0.001376   0.000960       0.001780     0.001708   0.001258
# 17     0.001228   0.000762       0.001710     0.001532   0.001472
# 18     0.001252   0.000730       0.001560     0.001476   0.001368
# 19     0.001438   0.000732       0.001582     0.001348   0.001398
#
#     R_20_denormal  U_20_normal  U_20_semi  U_20_denormal  D_20_normal  \
# 0        0.004258     0.026638   0.041170       0.078866     0.005984
# 1        0.001562     0.019588   0.024596       0.029390     0.002730
# 2        0.001550     0.018404   0.021278       0.025430     0.002734
# 3        0.001572     0.017684   0.020594       0.024984     0.003012
# 4        0.002112     0.020918   0.020804       0.026152     0.003196
# 5        0.002130     0.016416   0.021654       0.026184     0.003170
# 6        0.001678     0.017166   0.021328       0.025388     0.002382
# 7        0.001724     0.020286   0.020678       0.027974     0.003316
# 8        0.001420     0.018994   0.024212       0.022838     0.002418
# 9        0.001590     0.017578   0.019244       0.022708     0.002590
# 10       0.001568     0.019758   0.022858       0.026792     0.002842
# 11       0.001418     0.019864   0.020742       0.025166     0.004996
# 12       0.001508     0.018438   0.020332       0.030804     0.003122
# 13       0.001510     0.021456   0.020266       0.026294     0.003648
# 14       0.001518     0.019704   0.022496       0.028456     0.003080
# 15       0.001638     0.017724   0.020202       0.023976     0.002498
# 16       0.001468     0.018888   0.019330       0.024744     0.002576
# 17       0.001946     0.018120   0.020768       0.021800     0.002892
# 18       0.002616     0.019674   0.020964       0.025054     0.002808
# 19       0.001446     0.016360   0.020296       0.024906     0.004230
#
#     D_20_semi  D_20_denormal
# 0    0.003700       0.007488
# 1    0.001798       0.002202
# 2    0.001886       0.002366
# 3    0.001774       0.002058
# 4    0.001602       0.003240
# 5    0.001460       0.001980
# 6    0.001826       0.002160
# 7    0.001358       0.002502
# 8    0.001604       0.002182
# 9    0.002212       0.001958
# 10   0.001750       0.002228
# 11   0.001578       0.002872
# 12   0.001804       0.002170
# 13   0.001624       0.001926
# 14   0.001862       0.001864
# 15   0.001836       0.001810
# 16   0.001782       0.001956
# 17   0.001726       0.002424
# 18   0.001728       0.002140
# 19   0.001934       0.001664

# %%
df.to_csv("tests_20.csv", index=False, sep=',')

# %%
df.describe()
# Out:
#        C_20_normal  C_20_semi  C_20_denormal  R_20_normal  R_20_semi  \
# count    20.000000  20.000000      20.000000    20.000000  20.000000
# mean      0.001464   0.000866       0.001780     0.002109   0.001523
# std       0.000405   0.000160       0.000379     0.001595   0.000505
# min       0.001216   0.000722       0.001394     0.001348   0.001258
# 25%       0.001275   0.000734       0.001576     0.001496   0.001374
# 50%       0.001375   0.000796       0.001644     0.001665   0.001392
# 75%       0.001476   0.000958       0.001806     0.001832   0.001431
# max       0.003106   0.001342       0.003126     0.008638   0.003618
#
#        R_20_denormal  U_20_normal  U_20_semi  U_20_denormal  D_20_normal  \
# count      20.000000    20.000000  20.000000      20.000000    20.000000
# mean        0.001812     0.019183   0.022191       0.028395     0.003211
# std         0.000650     0.002242   0.004682       0.012083     0.000908
# min         0.001418     0.016360   0.019244       0.021800     0.002382
# 25%         0.001510     0.017714   0.020323       0.024866     0.002695
# 50%         0.001570     0.018941   0.020786       0.025409     0.002952
# 75%         0.001779     0.019784   0.021864       0.027088     0.003226
# max         0.004258     0.026638   0.041170       0.078866     0.005984
#
#        D_20_semi  D_20_denormal
# count  20.000000      20.000000
# mean    0.001842       0.002459
# std     0.000473       0.001238
# min     0.001358       0.001664
# 25%     0.001619       0.001958
# 50%     0.001778       0.002165
# 75%     0.001842       0.002380
# max     0.003700       0.007488
